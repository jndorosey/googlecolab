# %% [markdown]
# <a href="https://colab.research.google.com/github/jndorosey/googlecolab/blob/main/2_3_Vis_Tabular_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import shutil

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import io

# %%
import pandas as pd

# %%
# !wget http://fryziggafl.net/static/fryziggafl.zip 

shutil.unpack_archive('fryziggafl.zip')
# Out:
# --2022-10-24 03:31:11--  http://fryziggafl.net/static/fryziggafl.zip
# Resolving fryziggafl.net (fryziggafl.net)... 162.255.119.230
# Connecting to fryziggafl.net (fryziggafl.net)|162.255.119.230|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://www.fryziggafl.net/static/fryziggafl.zip [following]
# --2022-10-24 03:31:12--  http://www.fryziggafl.net/static/fryziggafl.zip
# Resolving www.fryziggafl.net (www.fryziggafl.net)... 35.173.69.207
# Connecting to www.fryziggafl.net (www.fryziggafl.net)|35.173.69.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21454369 (20M) [application/zip]
# Saving to: ‘fryziggafl.zip’
#
# fryziggafl.zip      100%[===================>]  20.46M  7.93MB/s    in 2.6s
#
# 2022-10-24 03:31:15 (7.93 MB/s) - ‘fryziggafl.zip’ saved [21454369/21454369]

# %%
afl = pd.read_csv('fryziggafl.csv',  low_memory=False)

# %%
afl
# Out:
#         Unnamed: 0    venue_name  match_id match_home_team match_away_team  \
# 0                1  Brunswick St         1         Fitzroy         Carlton
# 1                2  Brunswick St         1         Fitzroy         Carlton
# 2                3  Brunswick St         1         Fitzroy         Carlton
# 3                4  Brunswick St         1         Fitzroy         Carlton
# 4                5  Brunswick St         1         Fitzroy         Carlton
# ...            ...           ...       ...             ...             ...
# 655658      655659           MCG     16355         Geelong          Sydney
# 655659      655660           MCG     16355         Geelong          Sydney
# 655660      655661           MCG     16355         Geelong          Sydney
# 655661      655662           MCG     16355         Geelong          Sydney
# 655662      655663           MCG     16355         Geelong          Sydney
#
# ...

# %%
afl_post_2000 = afl[(afl['match_date'] > '2000-01-01')]

# %%
afl_post_2000
# Out:
#         Unnamed: 0 venue_name  match_id match_home_team match_away_team  \
# 458463      458464        MCG     11728        Richmond       Melbourne
# 458464      458465        MCG     11728        Richmond       Melbourne
# 458465      458466        MCG     11728        Richmond       Melbourne
# 458466      458467        MCG     11728        Richmond       Melbourne
# 458467      458468        MCG     11728        Richmond       Melbourne
# ...            ...        ...       ...             ...             ...
# 655658      655659        MCG     16355         Geelong          Sydney
# 655659      655660        MCG     16355         Geelong          Sydney
# 655660      655661        MCG     16355         Geelong          Sydney
# 655661      655662        MCG     16355         Geelong          Sydney
# 655662      655663        MCG     16355         Geelong          Sydney
#
#         match_date match_local_time  match_attendance  match_round  \
# ...

# %%
plt.plot(afl_post_2000.match_winner,afl_post_2000.match_home_team_goals);

# %%
sns.scatterplot(afl_post_2000.match_home_team,afl_post_2000.match_winner);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(afl_post_2000.match_home_team,
                afl_post_2000.match_winner, 
                hue=afl_post_2000.goals, s=100);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
afl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655663 entries, 0 to 655662
# Data columns (total 81 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      655663 non-null  int64
#  1   venue_name                      655663 non-null  object
#  2   match_id                        655663 non-null  int64
#  3   match_home_team                 655663 non-null  object
#  4   match_away_team                 655663 non-null  object
#  5   match_date                      655663 non-null  object
#  6   match_local_time                655663 non-null  object
#  7   match_attendance                655663 non-null  int64
#  8   match_round                     655663 non-null  object
#  9   match_home_team_goals           655663 non-null  int64
#  10  match_home_team_behinds         655663 non-null  int64
#  11  match_home_team_score           655663 non-null  int64
# ...

# %%
afl_final_mini = afl_post_2000[['match_id', 'match_home_team', 'match_away_team', 'match_home_team_score', 'match_away_team_score', 'match_home_team_goals', 'match_away_team_goals', 'match_date', 'match_round', 'match_winner', 'match_margin']]

# %%
afl_final_mini
# Out:
#         match_id match_home_team match_away_team  match_home_team_score  \
# 458463     11728        Richmond       Melbourne                     94
# 458464     11728        Richmond       Melbourne                     94
# 458465     11728        Richmond       Melbourne                     94
# 458466     11728        Richmond       Melbourne                     94
# 458467     11728        Richmond       Melbourne                     94
# ...          ...             ...             ...                    ...
# 655658     16355         Geelong          Sydney                    133
# 655659     16355         Geelong          Sydney                    133
# 655660     16355         Geelong          Sydney                    133
# 655661     16355         Geelong          Sydney                    133
# 655662     16355         Geelong          Sydney                    133
#
#         match_away_team_score  match_home_team_goals  match_away_team_goals  \
# ...

# %%
plt.figure(figsize=(30, 10))
plt.title('Match Home Winner')

sns.scatterplot(afl_post_2000.match_home_team,
                afl_post_2000.match_winner, 
                hue=afl_post_2000.goals, s=100);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(30, 10))
plt.title('Match Winner Margin')

sns.scatterplot('match_winner',
                'match_home_team', 
                hue='match_margin',
                s=100, 
                data=afl_post_2000);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(36, 10))
plt.title('Home-Away Team Margin')

sns.scatterplot('match_away_team',
                'match_home_team', 
                hue='match_margin',
                s=100, 
                data=afl_post_2000);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(50, 10))
plt.title('Home Team Goals')

sns.scatterplot('match_away_team',
                'match_home_team', 
                hue='match_home_team_goals',
                s=100, 
                data=afl_post_2000);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
